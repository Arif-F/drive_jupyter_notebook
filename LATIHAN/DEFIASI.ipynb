# %%
import numpy as np
from scipy import stats 
import matplotlib.pyplot as plt, seaborn as sns

# %%
xa = stats.norm(-2,1).rvs(10000) #4=defiasi 
sns.kdeplot(x, color ='red',fill=True) 

xb = stats.norm(-2,2).rvs(10000) #standar defiasi
sns.kdeplot(xb, color='green', fill=True) 
# kesimpulan . jika rata rata di perbesar dia akan bergeser ke kanan sebaliknya ketika rata defiasainya di perkeceil
#makan bergeser ke kiri

x_standar = (xa - xa.mean()) / xa.std()
sns.kdeplot(x_standar, color='yellow', fill=True)
# Out:
# <AxesSubplot: ylabel='Density'>
